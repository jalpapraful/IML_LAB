# %%
#GADHIYA JALPA
#216270307103
'''Write a NumPy program to implement following operation
 to convert a list of numeric values into a one-dimensional NumPy 
array
 to create a 3x3 matrix with values ranging from 2 to 10
 to append values at the end of an array
 to create another shape from an array without changing its data(3*2 
to 2*3)'''

import numpy as np

# %%
#GADHIYA JALPA
#216270307103
#practical 2.1
a=[1,2,3,4]

a1=np.array(a)
print(a1)

# %%
#GADHIYA JALPA
#216270307103
#practical 2.2
value=np.arange(2,11)
matrix=value.reshape(3,3)
print(matrix)

# %%
#GADHIYA JALPA
#216270307103
#practical 2.3
c=np.array([1,2,3,4])
print("orignal array:",c)
d=np.append(c,[5,6])
print("appending array:",d)

# %%
#GADHIYA JALPA
#216270307103
#practical 2.4

arr=np.array([[1,2],
             [3,4],
             [5,6]])
reshaped_arr=arr.reshape(2,3)
print(reshaped_arr)
